# %%
import pandas as pd
import numpy as np

# %%
def load_dataset(path):
    df = pd.read_json(path).T
    df['text'] = df['text'].astype(str).fillna('text')
    df['manaValue'] = df['manaValue'].astype(str).fillna('manaValue')
    df['toughness'] = df['toughness'].astype(str).fillna('toughness')
    df['power'] = df['power'].astype(str).fillna('power')
    df['type'] = df['type'].astype(str).fillna('type')
    df.rename(columns={'index': 'card_name'}, inplace=True)
    return df

# %%
filepath = 'data_download/MyDataMTGv2.json'
df = load_dataset(filepath)
df
# Out:
#                    colorIdentity  colors convertedManaCost edhrecRank  \
# Tukatongue Thallid           [G]     [G]               1.0       9980
# Moriok Replica               [B]      []               3.0      13335
# Faerie Mechanist             [U]     [U]               4.0      14051
# Ilysian Caryatid             [G]     [G]               2.0       1393
# Centaur Omenreader           [G]     [G]               4.0      11696
# ...                          ...     ...               ...        ...
# Hellfire Mongrel             [R]     [R]               3.0      18730
# Corpse Explosion          [B, R]  [B, R]               3.0       8501
# Mogg Squad                   [R]     [R]               2.0      25802
# Roots of Wisdom              [G]     [G]               2.0       9293
# Raven Guild Master           [U]     [U]               3.0      14063
#
#                    isStarter   manaCost manaValue  \
# Tukatongue Thallid      True        {G}       1.0
# Moriok Replica           NaN        {3}       3.0
# Faerie Mechanist        True     {3}{U}       4.0
# Ilysian Caryatid         NaN     {1}{G}       2.0
# Centaur Omenreader       NaN     {3}{G}       4.0
# ...                      ...        ...       ...
# Hellfire Mongrel         NaN     {2}{R}       3.0
# Corpse Explosion         NaN  {1}{B}{R}       3.0
# Mogg Squad               NaN     {1}{R}       2.0
# Roots of Wisdom          NaN     {1}{G}       2.0
# Raven Guild Master       NaN  {1}{U}{U}       3.0
#
#                                                     name power    rarity  ...  \
# Tukatongue Thallid  0263d148-6b69-552f-aa8f-0e0a828a52c7     1    common  ...
# Moriok Replica      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6     2    common  ...
# Faerie Mechanist    209175f2-8a24-5b0f-92fc-dc572dd7cbca     2    common  ...
# Ilysian Caryatid    3b4223be-41a3-5adb-b9ee-5e871101eb30     1    common  ...
# Centaur Omenreader  f0cade63-ec0f-5182-b089-24d93faef530     3  uncommon  ...
# ...                                                  ...   ...       ...  ...
# Hellfire Mongrel    96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba     2  uncommon  ...
# Corpse Explosion    08fe876f-cc69-5e66-8bfe-695074ba2fcc   nan      rare  ...
# Mogg Squad          12e22e5e-d947-5039-b519-55138cf99ba0     3  uncommon  ...
# Roots of Wisdom     251de176-9a6a-5e83-a862-b24a3ca8a4bb   nan    common  ...
# Raven Guild Master  df3a0d04-a358-5da0-aad5-60516bc590f3     1      rare  ...
#
#                    attractionLights isFunny asciiName flavorName defense  \
# Tukatongue Thallid              NaN     NaN       NaN        NaN     NaN
# Moriok Replica                  NaN     NaN       NaN        NaN     NaN
# Faerie Mechanist                NaN     NaN       NaN        NaN     NaN
# Ilysian Caryatid                NaN     NaN       NaN        NaN     NaN
# Centaur Omenreader              NaN     NaN       NaN        NaN     NaN
# ...                             ...     ...       ...        ...     ...
# Hellfire Mongrel                NaN     NaN       NaN        NaN     NaN
# Corpse Explosion                NaN     NaN       NaN        NaN     NaN
# Mogg Squad                      NaN     NaN       NaN        NaN     NaN
# Roots of Wisdom                 NaN     NaN       NaN        NaN     NaN
# Raven Guild Master              NaN     NaN       NaN        NaN     NaN
#
#                    faceFlavorName hasAlternativeDeckLimit cardParts  \
# Tukatongue Thallid            NaN                     NaN       NaN
# Moriok Replica                NaN                     NaN       NaN
# Faerie Mechanist              NaN                     NaN       NaN
# Ilysian Caryatid              NaN                     NaN       NaN
# Centaur Omenreader            NaN                     NaN       NaN
# ...                           ...                     ...       ...
# Hellfire Mongrel              NaN                     NaN       NaN
# Corpse Explosion              NaN                     NaN       NaN
# Mogg Squad                    NaN                     NaN       NaN
# Roots of Wisdom               NaN                     NaN       NaN
# Raven Guild Master            NaN                     NaN       NaN
#
#                    isOversized isTextless
# Tukatongue Thallid         NaN        NaN
# Moriok Replica             NaN        NaN
# Faerie Mechanist           NaN        NaN
# Ilysian Caryatid           NaN        NaN
# Centaur Omenreader         NaN        NaN
# ...                        ...        ...
# Hellfire Mongrel           NaN        NaN
# Corpse Explosion           NaN        NaN
# Mogg Squad                 NaN        NaN
# Roots of Wisdom            NaN        NaN
# Raven Guild Master         NaN        NaN
#
# [26143 rows x 52 columns]

# %%
color_map = {
    "G": "green",
    "B": "black",
    "R": "red",
    "U": "blue",
    "W": "white",
    "C": "colorless"
}

df['colorIdentity'] = df['colorIdentity'].apply(lambda colors: [color_map[color] for color in colors])
df
# Out:
#                    colorIdentity  colors convertedManaCost edhrecRank  \
# Tukatongue Thallid       [green]     [G]               1.0       9980
# Moriok Replica           [black]      []               3.0      13335
# Faerie Mechanist          [blue]     [U]               4.0      14051
# Ilysian Caryatid         [green]     [G]               2.0       1393
# Centaur Omenreader       [green]     [G]               4.0      11696
# ...                          ...     ...               ...        ...
# Hellfire Mongrel           [red]     [R]               3.0      18730
# Corpse Explosion    [black, red]  [B, R]               3.0       8501
# Mogg Squad                 [red]     [R]               2.0      25802
# Roots of Wisdom          [green]     [G]               2.0       9293
# Raven Guild Master        [blue]     [U]               3.0      14063
#
#                    isStarter   manaCost manaValue  \
# Tukatongue Thallid      True        {G}       1.0
# Moriok Replica           NaN        {3}       3.0
# Faerie Mechanist        True     {3}{U}       4.0
# Ilysian Caryatid         NaN     {1}{G}       2.0
# Centaur Omenreader       NaN     {3}{G}       4.0
# ...                      ...        ...       ...
# Hellfire Mongrel         NaN     {2}{R}       3.0
# Corpse Explosion         NaN  {1}{B}{R}       3.0
# Mogg Squad               NaN     {1}{R}       2.0
# Roots of Wisdom          NaN     {1}{G}       2.0
# Raven Guild Master       NaN  {1}{U}{U}       3.0
#
#                                                     name power    rarity  ...  \
# Tukatongue Thallid  0263d148-6b69-552f-aa8f-0e0a828a52c7     1    common  ...
# Moriok Replica      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6     2    common  ...
# Faerie Mechanist    209175f2-8a24-5b0f-92fc-dc572dd7cbca     2    common  ...
# Ilysian Caryatid    3b4223be-41a3-5adb-b9ee-5e871101eb30     1    common  ...
# Centaur Omenreader  f0cade63-ec0f-5182-b089-24d93faef530     3  uncommon  ...
# ...                                                  ...   ...       ...  ...
# Hellfire Mongrel    96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba     2  uncommon  ...
# Corpse Explosion    08fe876f-cc69-5e66-8bfe-695074ba2fcc   nan      rare  ...
# Mogg Squad          12e22e5e-d947-5039-b519-55138cf99ba0     3  uncommon  ...
# Roots of Wisdom     251de176-9a6a-5e83-a862-b24a3ca8a4bb   nan    common  ...
# Raven Guild Master  df3a0d04-a358-5da0-aad5-60516bc590f3     1      rare  ...
#
#                    attractionLights isFunny asciiName flavorName defense  \
# Tukatongue Thallid              NaN     NaN       NaN        NaN     NaN
# Moriok Replica                  NaN     NaN       NaN        NaN     NaN
# Faerie Mechanist                NaN     NaN       NaN        NaN     NaN
# Ilysian Caryatid                NaN     NaN       NaN        NaN     NaN
# Centaur Omenreader              NaN     NaN       NaN        NaN     NaN
# ...                             ...     ...       ...        ...     ...
# Hellfire Mongrel                NaN     NaN       NaN        NaN     NaN
# Corpse Explosion                NaN     NaN       NaN        NaN     NaN
# Mogg Squad                      NaN     NaN       NaN        NaN     NaN
# Roots of Wisdom                 NaN     NaN       NaN        NaN     NaN
# Raven Guild Master              NaN     NaN       NaN        NaN     NaN
#
#                    faceFlavorName hasAlternativeDeckLimit cardParts  \
# Tukatongue Thallid            NaN                     NaN       NaN
# Moriok Replica                NaN                     NaN       NaN
# Faerie Mechanist              NaN                     NaN       NaN
# Ilysian Caryatid              NaN                     NaN       NaN
# Centaur Omenreader            NaN                     NaN       NaN
# ...                           ...                     ...       ...
# Hellfire Mongrel              NaN                     NaN       NaN
# Corpse Explosion              NaN                     NaN       NaN
# Mogg Squad                    NaN                     NaN       NaN
# Roots of Wisdom               NaN                     NaN       NaN
# Raven Guild Master            NaN                     NaN       NaN
#
#                    isOversized isTextless
# Tukatongue Thallid         NaN        NaN
# Moriok Replica             NaN        NaN
# Faerie Mechanist           NaN        NaN
# Ilysian Caryatid           NaN        NaN
# Centaur Omenreader         NaN        NaN
# ...                        ...        ...
# Hellfire Mongrel           NaN        NaN
# Corpse Explosion           NaN        NaN
# Mogg Squad                 NaN        NaN
# Roots of Wisdom            NaN        NaN
# Raven Guild Master         NaN        NaN
#
# [26143 rows x 52 columns]

# %%
import re

number_words = {
    "0": "zero",
    "1": "one",
    "2": "two",
    "3": "three",
    "4": "four",
    "5": "five",
    "6": "six",
    "7": "seven",
    "8": "eight",
    "9": "nine",
    "10": "ten",
    "11": "eleven",
    "12": "twelve",
    "13": "thirteen",
    "14": "fourteen",
    "15": "fifteen",
    "16": "sixteen",
    "17": "seventeen",
    "18": "eighteen",
    "19": "nineteen",
    "20": "twenty",
    "21": "twentyone",
    "22": "twentytwo",
    "23": "twentythree",
    "24": "twentyfour",
    "25": "twentyfive"
}

def convert_mana_cost(mana_string):
    # Match each symbol enclosed in braces (e.g., {G}, {3})
    if pd.isna(mana_string):
        return "zero"
    
    symbols = re.findall(r'\{(.*?)\}', mana_string)
    converted_symbols = []
    
    for symbol in symbols:
        if symbol.isdigit():  # If the symbol is a digit, get its word and add "colorless"
            converted_symbols.append(f"{number_words[symbol]} colorless")
        elif symbol in color_map:  # If the symbol is in color_map, replace it with the corresponding color
            converted_symbols.append(color_map[symbol])
    
    # Join the converted symbols with spaces
    return " ".join(converted_symbols)

df['manaCost'] = df['manaCost'].apply(convert_mana_cost)
df
# Out:
#                    colorIdentity  colors convertedManaCost edhrecRank  \
# Tukatongue Thallid       [green]     [G]               1.0       9980
# Moriok Replica           [black]      []               3.0      13335
# Faerie Mechanist          [blue]     [U]               4.0      14051
# Ilysian Caryatid         [green]     [G]               2.0       1393
# Centaur Omenreader       [green]     [G]               4.0      11696
# ...                          ...     ...               ...        ...
# Hellfire Mongrel           [red]     [R]               3.0      18730
# Corpse Explosion    [black, red]  [B, R]               3.0       8501
# Mogg Squad                 [red]     [R]               2.0      25802
# Roots of Wisdom          [green]     [G]               2.0       9293
# Raven Guild Master        [blue]     [U]               3.0      14063
#
#                    isStarter                 manaCost manaValue  \
# Tukatongue Thallid      True                    green       1.0
# Moriok Replica           NaN          three colorless       3.0
# Faerie Mechanist        True     three colorless blue       4.0
# Ilysian Caryatid         NaN      one colorless green       2.0
# Centaur Omenreader       NaN    three colorless green       4.0
# ...                      ...                      ...       ...
# Hellfire Mongrel         NaN        two colorless red       3.0
# Corpse Explosion         NaN  one colorless black red       3.0
# Mogg Squad               NaN        one colorless red       2.0
# Roots of Wisdom          NaN      one colorless green       2.0
# Raven Guild Master       NaN  one colorless blue blue       3.0
#
#                                                     name power    rarity  ...  \
# Tukatongue Thallid  0263d148-6b69-552f-aa8f-0e0a828a52c7     1    common  ...
# Moriok Replica      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6     2    common  ...
# Faerie Mechanist    209175f2-8a24-5b0f-92fc-dc572dd7cbca     2    common  ...
# Ilysian Caryatid    3b4223be-41a3-5adb-b9ee-5e871101eb30     1    common  ...
# Centaur Omenreader  f0cade63-ec0f-5182-b089-24d93faef530     3  uncommon  ...
# ...                                                  ...   ...       ...  ...
# Hellfire Mongrel    96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba     2  uncommon  ...
# Corpse Explosion    08fe876f-cc69-5e66-8bfe-695074ba2fcc   nan      rare  ...
# Mogg Squad          12e22e5e-d947-5039-b519-55138cf99ba0     3  uncommon  ...
# Roots of Wisdom     251de176-9a6a-5e83-a862-b24a3ca8a4bb   nan    common  ...
# Raven Guild Master  df3a0d04-a358-5da0-aad5-60516bc590f3     1      rare  ...
#
#                    attractionLights isFunny asciiName flavorName defense  \
# Tukatongue Thallid              NaN     NaN       NaN        NaN     NaN
# Moriok Replica                  NaN     NaN       NaN        NaN     NaN
# Faerie Mechanist                NaN     NaN       NaN        NaN     NaN
# Ilysian Caryatid                NaN     NaN       NaN        NaN     NaN
# Centaur Omenreader              NaN     NaN       NaN        NaN     NaN
# ...                             ...     ...       ...        ...     ...
# Hellfire Mongrel                NaN     NaN       NaN        NaN     NaN
# Corpse Explosion                NaN     NaN       NaN        NaN     NaN
# Mogg Squad                      NaN     NaN       NaN        NaN     NaN
# Roots of Wisdom                 NaN     NaN       NaN        NaN     NaN
# Raven Guild Master              NaN     NaN       NaN        NaN     NaN
#
#                    faceFlavorName hasAlternativeDeckLimit cardParts  \
# Tukatongue Thallid            NaN                     NaN       NaN
# Moriok Replica                NaN                     NaN       NaN
# Faerie Mechanist              NaN                     NaN       NaN
# Ilysian Caryatid              NaN                     NaN       NaN
# Centaur Omenreader            NaN                     NaN       NaN
# ...                           ...                     ...       ...
# Hellfire Mongrel              NaN                     NaN       NaN
# Corpse Explosion              NaN                     NaN       NaN
# Mogg Squad                    NaN                     NaN       NaN
# Roots of Wisdom               NaN                     NaN       NaN
# Raven Guild Master            NaN                     NaN       NaN
#
#                    isOversized isTextless
# Tukatongue Thallid         NaN        NaN
# Moriok Replica             NaN        NaN
# Faerie Mechanist           NaN        NaN
# Ilysian Caryatid           NaN        NaN
# Centaur Omenreader         NaN        NaN
# ...                        ...        ...
# Hellfire Mongrel           NaN        NaN
# Corpse Explosion           NaN        NaN
# Mogg Squad                 NaN        NaN
# Roots of Wisdom            NaN        NaN
# Raven Guild Master         NaN        NaN
#
# [26143 rows x 52 columns]

# %%
df['power'] = df['power'].apply(lambda x: number_words.get(x, x))
df['toughness'] = df['toughness'].apply(lambda x: number_words.get(x, x))
df
# Out:
#                    colorIdentity  colors convertedManaCost edhrecRank  \
# Tukatongue Thallid       [green]     [G]               1.0       9980
# Moriok Replica           [black]      []               3.0      13335
# Faerie Mechanist          [blue]     [U]               4.0      14051
# Ilysian Caryatid         [green]     [G]               2.0       1393
# Centaur Omenreader       [green]     [G]               4.0      11696
# ...                          ...     ...               ...        ...
# Hellfire Mongrel           [red]     [R]               3.0      18730
# Corpse Explosion    [black, red]  [B, R]               3.0       8501
# Mogg Squad                 [red]     [R]               2.0      25802
# Roots of Wisdom          [green]     [G]               2.0       9293
# Raven Guild Master        [blue]     [U]               3.0      14063
#
#                    isStarter                 manaCost manaValue  \
# Tukatongue Thallid      True                    green       1.0
# Moriok Replica           NaN          three colorless       3.0
# Faerie Mechanist        True     three colorless blue       4.0
# Ilysian Caryatid         NaN      one colorless green       2.0
# Centaur Omenreader       NaN    three colorless green       4.0
# ...                      ...                      ...       ...
# Hellfire Mongrel         NaN        two colorless red       3.0
# Corpse Explosion         NaN  one colorless black red       3.0
# Mogg Squad               NaN        one colorless red       2.0
# Roots of Wisdom          NaN      one colorless green       2.0
# Raven Guild Master       NaN  one colorless blue blue       3.0
#
#                                                     name  power    rarity  \
# Tukatongue Thallid  0263d148-6b69-552f-aa8f-0e0a828a52c7    one    common
# Moriok Replica      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6    two    common
# Faerie Mechanist    209175f2-8a24-5b0f-92fc-dc572dd7cbca    two    common
# Ilysian Caryatid    3b4223be-41a3-5adb-b9ee-5e871101eb30    one    common
# Centaur Omenreader  f0cade63-ec0f-5182-b089-24d93faef530  three  uncommon
# ...                                                  ...    ...       ...
# Hellfire Mongrel    96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba    two  uncommon
# Corpse Explosion    08fe876f-cc69-5e66-8bfe-695074ba2fcc    nan      rare
# Mogg Squad          12e22e5e-d947-5039-b519-55138cf99ba0  three  uncommon
# Roots of Wisdom     251de176-9a6a-5e83-a862-b24a3ca8a4bb    nan    common
# Raven Guild Master  df3a0d04-a358-5da0-aad5-60516bc590f3    one      rare
#
#                     ... attractionLights isFunny asciiName flavorName defense  \
# Tukatongue Thallid  ...              NaN     NaN       NaN        NaN     NaN
# Moriok Replica      ...              NaN     NaN       NaN        NaN     NaN
# Faerie Mechanist    ...              NaN     NaN       NaN        NaN     NaN
# Ilysian Caryatid    ...              NaN     NaN       NaN        NaN     NaN
# Centaur Omenreader  ...              NaN     NaN       NaN        NaN     NaN
# ...                 ...              ...     ...       ...        ...     ...
# Hellfire Mongrel    ...              NaN     NaN       NaN        NaN     NaN
# Corpse Explosion    ...              NaN     NaN       NaN        NaN     NaN
# Mogg Squad          ...              NaN     NaN       NaN        NaN     NaN
# Roots of Wisdom     ...              NaN     NaN       NaN        NaN     NaN
# Raven Guild Master  ...              NaN     NaN       NaN        NaN     NaN
#
#                    faceFlavorName hasAlternativeDeckLimit cardParts  \
# Tukatongue Thallid            NaN                     NaN       NaN
# Moriok Replica                NaN                     NaN       NaN
# Faerie Mechanist              NaN                     NaN       NaN
# Ilysian Caryatid              NaN                     NaN       NaN
# Centaur Omenreader            NaN                     NaN       NaN
# ...                           ...                     ...       ...
# Hellfire Mongrel              NaN                     NaN       NaN
# Corpse Explosion              NaN                     NaN       NaN
# Mogg Squad                    NaN                     NaN       NaN
# Roots of Wisdom               NaN                     NaN       NaN
# Raven Guild Master            NaN                     NaN       NaN
#
#                    isOversized isTextless
# Tukatongue Thallid         NaN        NaN
# Moriok Replica             NaN        NaN
# Faerie Mechanist           NaN        NaN
# Ilysian Caryatid           NaN        NaN
# Centaur Omenreader         NaN        NaN
# ...                        ...        ...
# Hellfire Mongrel           NaN        NaN
# Corpse Explosion           NaN        NaN
# Mogg Squad                 NaN        NaN
# Roots of Wisdom            NaN        NaN
# Raven Guild Master         NaN        NaN
#
# [26143 rows x 52 columns]

# %%
def replace_symbols(text):
    # Step 1: Replace {T} with "tap"
    text = text.replace("{T}", "tap")
    
    # Step 2: Replace {C}, {W}, {U}, etc., with corresponding color names
    for symbol, color in color_map.items():
        text = text.replace(f"{{{symbol}}}", color)
    
    # Step 3: Replace numbers in braces, like {1}, {2}, with word equivalents
    text = re.sub(r'\{(\d+)\}', lambda x: f"{number_words.get(x.group(1), x.group(1))} colorless ", text)

    # Step 4: Replace standalone numbers (e.g., 1/1) with word equivalents
    text = re.sub(r'(?<!\{)(\b\d+\b)', lambda x: number_words.get(x.group(1), x.group(1)), text)

    # Step 5: Replace "+" and "-" with "plus" and "minus"
    text = text.replace("+", "plus ").replace("-", "minus ")
    
    # Step 6: Replace "/" with "by"
    text = text.replace("/", " by ")
    
    return text

df['text'] = df['text'].apply(replace_symbols)
df['text']
# Out:
# Tukatongue Thallid    When Tukatongue Thallid dies, create a one by ...
# Moriok Replica        one colorless black, Sacrifice Moriok Replica:...
# Faerie Mechanist      Flying\nWhen Faerie Mechanist enters the battl...
# Ilysian Caryatid      tap: Add one mana of any color. If you control...
# Centaur Omenreader    As long as Centaur Omenreader is tapped, creat...
#                                             ...
# Hellfire Mongrel      At the beginning of each opponent's upkeep, if...
# Corpse Explosion      As an additional cost to cast this spell, exil...
# Mogg Squad            Mogg Squad gets minus one by minus one for eac...
# Roots of Wisdom       Mill three cards, then return a land card or E...
# Raven Guild Master    Whenever Raven Guild Master deals combat damag...
# Name: text, Length: 26143, dtype: object

# %%
df['card_name'] = df.index
df.to_csv('data_download/clean_df.csv', index=False)
df
# Out:
#                    colorIdentity  colors convertedManaCost edhrecRank  \
# Tukatongue Thallid       [green]     [G]               1.0       9980
# Moriok Replica           [black]      []               3.0      13335
# Faerie Mechanist          [blue]     [U]               4.0      14051
# Ilysian Caryatid         [green]     [G]               2.0       1393
# Centaur Omenreader       [green]     [G]               4.0      11696
# ...                          ...     ...               ...        ...
# Hellfire Mongrel           [red]     [R]               3.0      18730
# Corpse Explosion    [black, red]  [B, R]               3.0       8501
# Mogg Squad                 [red]     [R]               2.0      25802
# Roots of Wisdom          [green]     [G]               2.0       9293
# Raven Guild Master        [blue]     [U]               3.0      14063
#
#                    isStarter                 manaCost manaValue  \
# Tukatongue Thallid      True                    green       1.0
# Moriok Replica           NaN          three colorless       3.0
# Faerie Mechanist        True     three colorless blue       4.0
# Ilysian Caryatid         NaN      one colorless green       2.0
# Centaur Omenreader       NaN    three colorless green       4.0
# ...                      ...                      ...       ...
# Hellfire Mongrel         NaN        two colorless red       3.0
# Corpse Explosion         NaN  one colorless black red       3.0
# Mogg Squad               NaN        one colorless red       2.0
# Roots of Wisdom          NaN      one colorless green       2.0
# Raven Guild Master       NaN  one colorless blue blue       3.0
#
#                                                     name  power    rarity  \
# Tukatongue Thallid  0263d148-6b69-552f-aa8f-0e0a828a52c7    one    common
# Moriok Replica      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6    two    common
# Faerie Mechanist    209175f2-8a24-5b0f-92fc-dc572dd7cbca    two    common
# Ilysian Caryatid    3b4223be-41a3-5adb-b9ee-5e871101eb30    one    common
# Centaur Omenreader  f0cade63-ec0f-5182-b089-24d93faef530  three  uncommon
# ...                                                  ...    ...       ...
# Hellfire Mongrel    96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba    two  uncommon
# Corpse Explosion    08fe876f-cc69-5e66-8bfe-695074ba2fcc    nan      rare
# Mogg Squad          12e22e5e-d947-5039-b519-55138cf99ba0  three  uncommon
# Roots of Wisdom     251de176-9a6a-5e83-a862-b24a3ca8a4bb    nan    common
# Raven Guild Master  df3a0d04-a358-5da0-aad5-60516bc590f3    one      rare
#
#                     ... isFunny asciiName flavorName defense faceFlavorName  \
# Tukatongue Thallid  ...     NaN       NaN        NaN     NaN            NaN
# Moriok Replica      ...     NaN       NaN        NaN     NaN            NaN
# Faerie Mechanist    ...     NaN       NaN        NaN     NaN            NaN
# Ilysian Caryatid    ...     NaN       NaN        NaN     NaN            NaN
# Centaur Omenreader  ...     NaN       NaN        NaN     NaN            NaN
# ...                 ...     ...       ...        ...     ...            ...
# Hellfire Mongrel    ...     NaN       NaN        NaN     NaN            NaN
# Corpse Explosion    ...     NaN       NaN        NaN     NaN            NaN
# Mogg Squad          ...     NaN       NaN        NaN     NaN            NaN
# Roots of Wisdom     ...     NaN       NaN        NaN     NaN            NaN
# Raven Guild Master  ...     NaN       NaN        NaN     NaN            NaN
#
#                    hasAlternativeDeckLimit cardParts isOversized isTextless  \
# Tukatongue Thallid                     NaN       NaN         NaN        NaN
# Moriok Replica                         NaN       NaN         NaN        NaN
# Faerie Mechanist                       NaN       NaN         NaN        NaN
# Ilysian Caryatid                       NaN       NaN         NaN        NaN
# Centaur Omenreader                     NaN       NaN         NaN        NaN
# ...                                    ...       ...         ...        ...
# Hellfire Mongrel                       NaN       NaN         NaN        NaN
# Corpse Explosion                       NaN       NaN         NaN        NaN
# Mogg Squad                             NaN       NaN         NaN        NaN
# Roots of Wisdom                        NaN       NaN         NaN        NaN
# Raven Guild Master                     NaN       NaN         NaN        NaN
#
#                              card_name
# Tukatongue Thallid  Tukatongue Thallid
# Moriok Replica          Moriok Replica
# Faerie Mechanist      Faerie Mechanist
# Ilysian Caryatid      Ilysian Caryatid
# Centaur Omenreader  Centaur Omenreader
# ...                                ...
# Hellfire Mongrel      Hellfire Mongrel
# Corpse Explosion      Corpse Explosion
# Mogg Squad                  Mogg Squad
# Roots of Wisdom        Roots of Wisdom
# Raven Guild Master  Raven Guild Master
#
# [26143 rows x 53 columns]

# %%
df_new = pd.read_csv('data_download/clean_df.csv')
df_new
# Out:
# /tmp/ipykernel_6921/2971629831.py:1: DtypeWarning: Columns (34,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv('data_download/clean_df.csv')
#           colorIdentity      colors  convertedManaCost  edhrecRank isStarter  \
# 0             ['green']       ['G']                1.0      9980.0      True
# 1             ['black']          []                3.0     13335.0       NaN
# 2              ['blue']       ['U']                4.0     14051.0      True
# 3             ['green']       ['G']                2.0      1393.0       NaN
# 4             ['green']       ['G']                4.0     11696.0       NaN
# ...                 ...         ...                ...         ...       ...
# 26138           ['red']       ['R']                3.0     18730.0       NaN
# 26139  ['black', 'red']  ['B', 'R']                3.0      8501.0       NaN
# 26140           ['red']       ['R']                2.0     25802.0       NaN
# 26141         ['green']       ['G']                2.0      9293.0       NaN
# 26142          ['blue']       ['U']                3.0     14063.0       NaN
#
#                       manaCost  manaValue  \
# 0                        green        1.0
# 1              three colorless        3.0
# 2         three colorless blue        4.0
# 3          one colorless green        2.0
# 4        three colorless green        4.0
# ...                        ...        ...
# 26138        two colorless red        3.0
# 26139  one colorless black red        3.0
# 26140        one colorless red        2.0
# 26141      one colorless green        2.0
# 26142  one colorless blue blue        3.0
#
#                                        name  power    rarity  ... isFunny  \
# 0      0263d148-6b69-552f-aa8f-0e0a828a52c7    one    common  ...     NaN
# 1      a9a8ce3a-2d95-566c-b3d3-d7ada7cf2ad6    two    common  ...     NaN
# 2      209175f2-8a24-5b0f-92fc-dc572dd7cbca    two    common  ...     NaN
# 3      3b4223be-41a3-5adb-b9ee-5e871101eb30    one    common  ...     NaN
# 4      f0cade63-ec0f-5182-b089-24d93faef530  three  uncommon  ...     NaN
# ...                                     ...    ...       ...  ...     ...
# 26138  96fc59f6-41ce-5b8f-b94e-d1bb8f7d79ba    two  uncommon  ...     NaN
# 26139  08fe876f-cc69-5e66-8bfe-695074ba2fcc    NaN      rare  ...     NaN
# 26140  12e22e5e-d947-5039-b519-55138cf99ba0  three  uncommon  ...     NaN
# 26141  251de176-9a6a-5e83-a862-b24a3ca8a4bb    NaN    common  ...     NaN
# 26142  df3a0d04-a358-5da0-aad5-60516bc590f3    one      rare  ...     NaN
#
#       asciiName flavorName defense faceFlavorName hasAlternativeDeckLimit  \
# 0           NaN        NaN     NaN            NaN                     NaN
# 1           NaN        NaN     NaN            NaN                     NaN
# 2           NaN        NaN     NaN            NaN                     NaN
# 3           NaN        NaN     NaN            NaN                     NaN
# 4           NaN        NaN     NaN            NaN                     NaN
# ...         ...        ...     ...            ...                     ...
# 26138       NaN        NaN     NaN            NaN                     NaN
# 26139       NaN        NaN     NaN            NaN                     NaN
# 26140       NaN        NaN     NaN            NaN                     NaN
# 26141       NaN        NaN     NaN            NaN                     NaN
# 26142       NaN        NaN     NaN            NaN                     NaN
#
#        cardParts isOversized isTextless           card_name
# 0            NaN         NaN        NaN  Tukatongue Thallid
# 1            NaN         NaN        NaN      Moriok Replica
# 2            NaN         NaN        NaN    Faerie Mechanist
# 3            NaN         NaN        NaN    Ilysian Caryatid
# 4            NaN         NaN        NaN  Centaur Omenreader
# ...          ...         ...        ...                 ...
# 26138        NaN         NaN        NaN    Hellfire Mongrel
# 26139        NaN         NaN        NaN    Corpse Explosion
# 26140        NaN         NaN        NaN          Mogg Squad
# 26141        NaN         NaN        NaN     Roots of Wisdom
# 26142        NaN         NaN        NaN  Raven Guild Master
#
# [26143 rows x 53 columns]

# %%
def get_names_descriptions(df):
    df['description'] = df['text'] + ' cost ' + df['manaCost'] + ' toughness ' + df['toughness'] + ' power ' + df['power'] + ' types ' + df['type']
    return df['card_name'].values, df['description'].values

card_names, card_descriptions = get_names_descriptions(df_new)

card_names, card_descriptions
# Out:
# (array(['Tukatongue Thallid', 'Moriok Replica', 'Faerie Mechanist', ...,
#         'Mogg Squad', 'Roots of Wisdom', 'Raven Guild Master'],
#        dtype=object),
#  array(['When Tukatongue Thallid dies, create a one by one green Saproling creature token. cost green toughness one power one types Creature — Fungus',
#         'one colorless black, Sacrifice Moriok Replica: You draw two cards and you lose two life. cost three colorless toughness two power two types Artifact Creature — Warrior',
#         'Flying\nWhen Faerie Mechanist enters the battlefield, look at the top three cards of your library. You may reveal an artifact card from among them and put it into your hand. Put the rest on the bottom of your library in any order. cost three colorless blue toughness two power two types Artifact Creature — Faerie Artificer',
#         ...,
#         'Mogg Squad gets minus one by minus one for each other creature on the battlefield. cost one colorless red toughness three power three types Creature — Goblin',
#         nan,
#         'Whenever Raven Guild Master deals combat damage to a player, that player exiles the top ten cards of their library.\nMorph two colorless blueblue (You may cast this card face down as a two by two creature for three colorless . Turn it face up any time for its morph cost.) cost one colorless blue blue toughness one power one types Creature — Human Wizard Mutant'],
#        dtype=object))
